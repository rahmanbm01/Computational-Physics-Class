# %%
import numpy as np
import matplotlib.pyplot as plt
file1=open("Pb1_C++.txt",'r')
#file1.readlines()
array1=[]
array2=[]
for line in file1:
   # print(line)
   # print(type(line))
    a=len(line.split())
    index=0
    for i in np.arange(0,a):
        if len(array1)<a:
            array1.append(float(line.split()[i]))
        else:
        
            array2.append(float(line.split()[i]))
    #print(len(line.split()))
    #field.append
print(array1)
print(array2)
plt.plot(array1,array2, marker="*")
plt.xlabel('time_step')
plt.ylabel('|error in gradient|')
plt.title('Problem1_C++')
plt.yscale("log")
plt.xscale("log")
plt.show()
plt.savefig('Problem1_C++_final.png')
# Out:
# [1.0, 0.1, 0.01, 0.001, 0.0001, 1e-05, 1e-06, 1e-07, 1e-08, 1e-09, 1e-10, 1e-11, 1e-12, 1e-13, 1e-14, 1e-15, 1e-16, 1e-17, 1e-18, 1e-19, 1e-20, 1e-21]
# [0.00786978, 0.00101466, 0.000119675, 1.2148e-05, 1.2166e-06, 1.21677e-07, 1.217e-08, 6.2366e-10, 2.28899e-09, 1.43644e-08, 4.02942e-07, 6.2584e-06, 4.84383e-06, 0.000550268, 0.0133178, 0.0299712, 0.247585, 0.247585, 0.247585, 0.247585, 0.247585, 0.247585]
